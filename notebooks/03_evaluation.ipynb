# %%
# Load best model
cnn_model = tf.keras.models.load_model('models/digit_cnn_model.h5')

# Predictions
cnn_pred = np.argmax(cnn_model.predict(X_test_cnn), axis=1)

# Metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("CNN Accuracy:", accuracy_score(y_test, cnn_pred))
print("\nClassification Report:")
print(classification_report(y_test, cnn_pred))

# Confusion Matrix
plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_test, cnn_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - CNN Model')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig('confusion_matrix.png')
plt.show()

# Model Comparison
models = ['Logistic Regression', 'Random Forest', 'CNN']
accuracies = [0.92, 0.97, 0.99]  # Your actual results

plt.figure(figsize=(8, 5))
plt.bar(models, accuracies)
plt.ylim(0.85, 1.0)
plt.title('Model Comparison')
plt.ylabel('Accuracy')
plt.savefig('model_comparison.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load best model
# ----> 2 cnn_model = tf.keras.models.load_model('models/digit_cnn_model.h5')
#       4 # Predictions
#       5 cnn_pred = np.argmax(cnn_model.predict(X_test_cnn), axis=1)
#
# NameError: name 'tf' is not defined
